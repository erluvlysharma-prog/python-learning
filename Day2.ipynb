# %% [markdown]
# <a href="https://colab.research.google.com/github/erluvlysharma-prog/python-learning/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.  Check whether a number is positive, negative, or zero.
n = int(input("Enter a number: "))
if n > 0:
  print("Number is positive")
elif n < 0:
  print("Number is negative")
else:
  print("Number is zero")

# %%
 # 2. Check whether a number is even or odd.
n = int(input("Enter a number: "))
if n%2 == 0:
  print("Number is even")
else:
  print("Number is odd")

# %%
# 3.Find the larger of two numbers.
a = int(input("Enter the first number: "))
b = int(input("Enter the first number: "))
if a > b:
  print("First number is larger")
elif b > a:
  print("Second number is larger")
else:
  print("Both numbers are equal")

# %%
# 4.  Find the largest of three numbers.
a = int(input("Enter the first number: "))
b = int(input("Enter the first number: "))
c = int(input("Enter the first number: "))
if a>b and a>c:
  print("Frist number is largest")
elif b>a and b>c:
  print("Second number is largest")
else :
  print("Third number is largest")

# %%
# 5.  Find the smallest of three numbers.
a = int(input("Enter the first number: "))
b = int(input("Enter the first number: "))
c = int(input("Enter the first number: "))
if a<b and a<c:
  print("Frist number is smallesr")
elif b<a and b<c:
  print("Second number is smallest")
else :
  print("Third number is smallest")

# %%
# 6.  Check whether a person is eligible to vote based on age.
age = int(input("Enter the age: "))
if age >= 18:
  print("Person is eligible to vote")
else:
  print("Person is not eligible to vote")

# %%
# 7.  Check whether a year is a leap year.
year = int(input("Enter the year:"))
if year % 4 == 0:
  print("Year is a leap year")
else:
  print("Year is not a leap year")

# %%
# 8.  Check whether a character is a vowel or consonant.
char = input("Enter the character: ")
if char == 'a' and char == 'e' and char == 'i' and char == 'o' and char == 'u':
  print("Character is a vowel")
else:
  print("Character is a consonant")

# %%
# 9.  Check whether a character is an alphabet, digit, or special character.
char = input("Enter the character: ")
if char.isalpha():
  print("Character is an alphabet")
elif char.isdigit():
  print("Character is a digit")
else:
  print("Character is a special character")

# %%
# 10. Check whether a number is divisible by both 5 and 11.
num = int(input("Enter the number : "))
if num % 5 == 0 and num % 11 == 0:
  print("Number is divisible by both 5 and 11")
else:
  print("Number is not divisible by both 5 and 11")

# %%
# 11. Check whether a number is divisible by 3 or 7.
num = int(input("Enter the number : "))
if num % 3 == 0 or num % 7 == 0:
  print("Number is divisible by 3 or 7")
else:
  print("Number is not divisible by 3 or 7")

# %%
# 12. Check whether three sides can form a valid triangle.
a = int(input("Enter the first side: "))
b = int(input("Enter the second side: "))
c = int(input("Enter the third side: "))
if a + b > c and b + c > a and c + a > b:
  print("Three sides can form a valid triangle")
else:
  print("Three sides can not form a valid triangle")

# %%
# 13. Determine whether a triangle is equilateral, isosceles, or scalene.
a = int(input("Enter the first side: "))
b = int(input("Enter the second side: "))
c = int(input("Enter the third side: "))
if a == b == c:
  print("This triangle is equilateral.")
elif a == b and b == c and c == a:
  print("This triangle is isosceles.")
else:
  print("This triangle is scalene.")

# %%
# 14. Determine whether a triangle is acute, right, or obtuse using its sides.
a = int(input("Enter the first side: "))
b = int(input("Enter the second side: "))
c = int(input("Enter the third side: "))
if a**2 + b**2 == c**2:
  print("This triangle is right angled.")
elif a**2 + b**2 < c**2:
  print("This triangle is acute angled.")
else:
  print("This triangle is obtuse angled.")

# %%
# 15. Calculate grade from marks using if/else conditions.
marks = int(input("Enter the marks:"))
if marks >= 90:
  print("Grade A")
elif marks >= 80:
  print("Grade B")
elif marks >= 70:
  print("Grade C")
elif marks >= 60:
  print("Grade D")
elif marks >= 50:
  print("Grade E")
else:
  print("Grade F")

# %%
# 16. Calculate electricity bill using slab-based conditions.
unit = int(input("Enter the unit"))
if unit <= 150:
  bill = unit* 5
elif 150 < unit <= 300:
  bill = unit * 5 + (unit - 150) * 7
else:
  bill = unit * 5 + unit * 7 + (unit - 150) * 9
print("Your electricity bill : ",bill)

# %%
# 17. Calculate income tax using given income slabs
income = float(input("Enter your annual income: "))

if income <= 250000:
    tax = 0
elif income <= 500000:
    tax = (income - 250000) * 0.05
elif income <= 1000000:
    tax = (250000 * 0.05) + ((income - 500000) * 0.20)
else:
    tax = (250000 * 0.05) + (500000 * 0.20) + ((income - 1000000) * 0.30)

print("Income Tax:", tax)

# %%
# 18. Check whether a number lies inside a given range.
num = int(input("Enter a number: "))
lower = int(input("Enter lower limit: "))
upper = int(input("Enter upper limit: "))

if lower <= num <= upper:
    print("Number lies inside the range.")
else:
    print("Number does not lie inside the range.")

# %%
# 19. Calculate absolute value without using an absolute-value function.
num = float(input("Enter a number: "))
if num <0:
  num = -num

print("Absolute value:", num)

# %%
# 20. Find the middle value among three distinct numbers.
x = int(input("Enter the first number: "))
y = int(input("Enter the second number: "))
z = int(input("Enter the third number: "))
if x < y < z or x > y > z:
  print("Middle value is: ",y)
elif z < y < z or z > y > x:
  print("Middle value is: ",z)
else:
  print("Middle value is: ",x)

# %%
num = int(input("Enter a number: "))
match num:
  case 1:
    print("Monday")
  case 2:
    print("Tuesday")
  case 3:
    print("Wednesday")
  case 4:
    print("Thursday")
  case 5:
    print("Friday")
  case 6:
    print("Saturday")
  case 7:
    print("Sunday")
  case _:
        print("Invalid week number")

# %%
# 22. Print the month name for numbers 1–12

num = int(input("Enter a number (1-12): "))

match num:
    case 1:
        print("January")
    case 2:
        print("February")
    case 3:
        print("March")
    case 4:
        print("April")
    case 5:
        print("May")
    case 6:
        print("June")
    case 7:
        print("July")
    case 8:
        print("August")
    case 9:
        print("September")
    case 10:
        print("October")
    case 11:
        print("November")
    case 12:
        print("December")
    case _:
        print("Invalid month number")

# %%
# 23. Build a calculator using +, -, *, /, and % operators.
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
case = input("Enter the operation:")
match case:
  case "+":
    print("Addition of two numbers is: ",a+b)
  case "-" :
    print("Subtraction of two numbers is: ",a-b)
  case "*":
    print("Multiplication of two number is: ",a*b)
  case "%":
    print("Modulus of two numbers is: ",a%b)
  case _:
    print("Invalid operation")

# %%
# 24. Convert a number 1–12 into the number of days in that month.
month = int(input("Enter month number (1-12): "))

match month:
    case 1 | 3 | 5 | 7 | 8 | 10 | 12:
        print("31 days")
    case 4 | 6 | 9 | 11:
        print("30 days")
    case 2:
        print("28 days")
    case _:
        print("Invalid month number")

# %%
# 25. Build a menu-driven program for addition, subtraction, multiplication, and division.

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice: "))

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

match choice:
    case 1:
      print("Addition: ",a +b)
    case 2:
      print("Subtraction: ",a - b)
    case 3:
      print("Multiplication: ",a * b)
    case 4:
      if b == 0:
        print("Division by zero is not allowed")
      else:
        print("Division", a / b)
    case _:
      print("Invalid choice")

# %%
# 26. Convert temperature between Celsius, Fahrenheit, and Kelvin using a menu.

print("1. Celsius to Fahrenheit")
print("2. Fahrenheit to Celsius")
print("3. Celsius to Kelvin")
print("4. Kelvin to Celsius")
print("5. Fahrenheit to Kelvin")
print("6. Kelvin to Fahrenheit")

choice = int(input("Enter your choice: "))

temp = float(input("Enter temperature: "))

match choice:
    case 1:
        print("Fahrenheit: ", (temp * 9/5) + 32)
    case 2:
        print("Celsius: ", (temp - 32) * 5/9)
    case 3:
        print("Kelvin: ", temp + 273.15)
    case 4:
        print("Celsius: ", temp - 273.15)
    case 5:
        print("Kelvin: ", (temp - 32) * 5/9 + 273.15)
    case 6:
        print("Fahrenheit: ", (temp - 273.15) * 9/5 + 32)
    case _:
        print("Invalid choice")

# %%
# 27. Convert units: km/miles/meters using a menu.

print("1. Kilometers to Miles")
print("2. Miles to Kilometers")
print("3. Kilometers to Meters")
print("4. Meters to Kilometers")
print("5. Miles to Meters")
print("6. Meters to Miles")

choice = int(input("Enter your choice (1-6): "))
value = float(input("Enter value: "))

match choice:
    case 1:
        print("Miles:", value * 0.621371)
    case 2:
        print("Kilometers:", value * 1.60934)
    case 3:
        print("Feet:", value * 3.28084)
    case 4:
        print("Meters:", value * 0.3048)
    case 5:
        print("Pounds:", value * 2.20462)
    case 6:
        print("Kilograms:", value * 0.453592)
    case _:
        print("Invalid choice")

# %%
# 28. Print whether a character is a vowel using switch/case.

char = input("Enter a character: ")

match char:
    case 'a' | 'e' | 'i' | 'o' | 'u' | 'A' | 'E' | 'I' | 'O' | 'U':
        print("Vowel")
    case _:
        print("Consonant")

# %%
# 29. Create a menu for checking even/odd, positive/negative, or prime

print("1. Check Even/Odd")
print("2. Check Positive/Negative")
print("3. Check Prime")

choice = int(input("Enter your choice (1-3): "))
num = int(input("Enter a number: "))

match choice:
    case 1:
        if num % 2 == 0:
            print("Even")
        else:
            print("Odd")

    case 2:
        if num > 0:
            print("Positive")
        elif num < 0:
            print("Negative")
        else:
            print("Zero")

    case 3:
        if num < 2:
            print("Not Prime")
        else:
            is_prime = True

            for i in range(2, num):
                if num % i == 0:
                    is_prime = False
                    break

            if is_prime:
                print("Prime")
            else:
                print("Not Prime")

    case _:
        print("Invalid choice")

# %%
# 30. Create a simple ATM menu: balance, deposit, withdraw, exit.

print("1. Check Balance")
print("2. Deposit")
print("3. Withdraw")
print("4. Exit")

choice = int(input("Enter your choice (1-4): "))
balance = 1000

match choice:
    case 1:
        print("Balance:", balance)
    case 2:
        amount = float(input("Enter deposit amount: "))
        balance += amount
        print("Balance:", balance)
    case 3:
        amount = float(input("Enter withdrawal amount: "))
        if amount > balance:
            print("Insufficient balance")
        else:
            balance -= amount
            print("Balance:", balance)
    case 4:
        print("Thank you for using the ATM")
    case _:
        print("Invalid choice")

# %%
# 31. Create a menu-driven area calculator for circle, rectangle, square, and triangle.

print("1. Calculate area for circle")
print("2. Calculate area for rectangle")
print("3. Calculate area for square")
print("4. Calculate area for triangle")

choice = int(input("Enter your choice (1-4): "))

match choice:
    case 1:
        radius = float(input("Enter radius: "))
        print("Area of circle:", 3.14 * radius * radius)

    case 2:
        length = float(input("Enter length: "))
        width = float(input("Enter width: "))
        print("Area of rectangle:", length * width)

    case 3:
        side = float(input("Enter side: "))
        print("Area of square:", side * side)

    case 4:
        base = float(input("Enter base: "))
        height = float(input("Enter height: "))
        print("Area of triangle:", 0.5 * base * height)

    case _:
        print("Invalid choice")

# %%
# 32. Create a menu-driven number utility:
# factorial, reverse, digit sum, palindrome

print("1. Factorial")
print("2. Reverse")
print("3. Digit Sum")
print("4. Palindrome")

choice = int(input("Enter your choice (1-4): "))
num = int(input("Enter a number: "))

match choice:

    case 1:
        factorial = 1

        for i in range(1, num + 1):
            factorial = factorial * i

        print("Factorial:", factorial)

    case 2:
        reverse = 0
        temp = num

        while temp > 0:
            digit = temp % 10
            reverse = reverse * 10 + digit
            temp = temp // 10

        print("Reverse:", reverse)

    case 3:
        digit_sum = 0
        temp = num

        while temp > 0:
            digit = temp % 10
            digit_sum = digit_sum + digit
            temp = temp // 10

        print("Digit Sum:", digit_sum)

    case 4:
        reverse = 0
        temp = num

        while temp > 0:
            digit = temp % 10
            reverse = reverse * 10 + digit
            temp = temp // 10

        if num == reverse:
            print("Palindrome")
        else:
            print("Not Palindrome")

    case _:
        print("Invalid choice")

# %%
# 33. Create a restaurant billing menu with item selection and quantity.

print("------------ Menu -----------")
print("1. Chhole Bhature     /-150")
print("2. Dahi Bhalle        /-200")
print("3. Sabji Puri         /-120")
print("4. Aallu Paratha      /-80")

choice = int(input("Enter your choice: "))
quantity = int(input("Enter quantity: "))

match choice:
    case 1:
        item = "Chhole Bhature"
        price = 150

    case 2:
        item = "Dahi Bhalle"
        price = 200

    case 3:
        item = "Sabji Puri"
        price = 120

    case 4:
        item = "Aallu Paratha"
        price = 80

    case _:
        print("Invalid choice")
        exit()

total = price * quantity

print("-------- BILL --------")
print("Item: ", item)
print("Quantity: ", quantity)
print("Price: ₹", price)
print("Total: ₹", total)

# %%
# 34. Create a simple traffic-light program for red, yellow, and green.

light = input("Enter traffic light color: ").lower()

match light:
    case "red":
        print("Stop")
    case "yellow":
        print("Get Ready")
    case "green":
        print("Go")
    case _:
        print("Invalid traffic light color")

# %%
# 35. Create a menu-driven conversion program for binary, decimal, and hexadecimal values.

print("1. Binary to Decimal")
print("2. Decimal to Binary")
print("3. Binary to Hexadecimal")
print("4. Hexadecimal to Binary")
print("5. Decimal to Hexadecimal")
print("6. Hexadecimal to Decimal")

choice = int(input("Enter your choice (1-6): "))

match choice:
    case 1:
        binary = input("Enter binary value: ")
        decimal = int(binary, 2)
        print("Decimal:", decimal)

    case 2:
        decimal = int(input("Enter decimal value: "))
        binary = bin(decimal)[2:]
        print("Binary:", binary)

    case 3:
        binary = input("Enter binary value: ")
        hexadecimal = hex(int(binary, 2))[2:]
        print("Hexadecimal:", hexadecimal)

    case 4:
        hexadecimal = input("Enter hexadecimal value: ")
        binary = bin(int(hexadecimal, 16))[2:]
        print("Binary:", binary)

    case 5:
        decimal = int(input("Enter decimal value: "))
        hexadecimal = hex(decimal)[2:]
        print("Hexadecimal:", hexadecimal)

    case 6:
        hexadecimal = input("Enter hexadecimal value: ")
        decimal = int(hexadecimal, 16)
        print("Decimal:", decimal)

    case _:
        print("Invalid choice")

# %%
# 36. Print numbers from 1 to N.
n = int(input("Enter a number: "))
for i in range(1, n + 1):
    print(i)

# %%
# 37. Print numbers from N to 1.
n = int(input("Enter a number: "))
for i in range(n, 0, -1):
    print(i)

# %%
# 38. Print all even numbers from 1 to N.
n = int(input("Enter a number: "))
for i in range(2, n + 1, 2):
    print(i)

# %%
# 39. Print all odd numbers from 1 to N.
n = int(input("Enter a number: "))
for i in range(1, n + 1, 2):
    print(i)

# %%
# 40. Find the sum of numbers from 1 to N.
n = int(input("Enter a number: "))
sum = 0
for i in range(1, n + 1):
    sum += i
print("Sum of numbers from 1 to", n, "is", sum)

# %%
# 41. Find the sum of even numbers from 1 to N.
n = int(input("Enter a number: "))
sum = 0
for i in range(2, n+1, 2):
    sum += i
print("Sum of even numbers", sum)

# %%
# 41. Find the sum of even numbers from 1 to N.
n = int(input("Enter a number: "))
sum = 0
for i in range(1, n+1, 2):
    sum += i
print("Sum of odd numbers", sum)

# %%
# 42. Find the sum of odd numbers from 1 to N.
n = int(input("Enter a number: "))
sum = 0
for i in range(1, n+1, 2):
      sum += i
print("Sum of odd numbers", sum)

# %%
# 43. Find the average of numbers from 1 to N.
n = int(input("Enter a number: "))
sum = 0
for i in range(1, n+1):
      sum += i
print("Average of numbers", sum/n)

# %%
# 44. Print the multiplication table of N.
n = int(input("Enter a number: "))
for i in range(1, 11):
      print(n, "x", i, "=", n*i)

# %%
# 45. Print multiplication tables from 1 to 10.
for i in range(1, 11):
      print("Multiplication table of", i)
      for j in range(1, 11):
            print(i, "x", j, "=", i*j)

# %%
# 46. Calculate N factorial.
n = int(input("Enter a number:"))
factorial = 1
for i in range(1, n+1):
  factorial*= i
print(factorial)

# %%
# 47. Calculate the sum of squares from 1 to N.
n = int(input("Enter a number:"))
sum = 0
for i in range(1, n+1):
  sum+= i*i
print(sum)

# %%
# 48. Calculate the sum of cubes from 1 to N.
n = int(input("Enter a number:"))
sum = 0
for i in range(1, n+1):
  sum+= i*i*i
print(sum)

# %%
# 49. Count how many numbers from 1 to N are divisible by 3.
n = int(input("Enter a number:"))
count = 0
for i in range(1, n+1):
  if i % 3 == 0:
    count += 1
print(count)

# %%
# 50. Count numbers divisible by both 3 and 5 from 1 to N.
n = int(input("Enter a number:"))
count = 0
for i in range(1, n+1):
  if i % 3 == 0 and i % 5 == 0:
    count += 1
print(count)

# %%
# 51. Print all numbers in a given range divisible by N.
start = int(input("Enter start of range:"))
end = int(input("Enter end of range:"))
n = int(input("Enter a number:"))
for i in range(start, end+1):
  if i % n == 0:
    print(i)

# %%
# 52. Find the sum of all numbers in a given range.
start = int(input("Enter start of range:"))
end = int(input("Enter end of range:"))
sum = 0
for i in range(start, end+1):
 sum += i
print(sum)

# %%
# 53. Find the product of numbers from 1 to N.
n = int(input("Enter a number:"))
product = 1
for i in range(1, n+1):
  product*= i
print(product)

# %%
# 54. Print the first N multiples of a number.
n = int(input("Enter a number:"))
m = int(input("Enter a number of multiples:"))
for i in range(1, m+1):
  print(n, "x", i, "=", n*i)

# %%
# 55. Print numbers between A and B without using a second loop.
a = int(input("Enter A: "))
b = int(input("Enter B: "))

for i in range(a, b + 1):
    print(i)

# %%
# 56. Find the largest number among N user-entered numbers.
n = int(input("How many numbers do you want to enter? "))

largest = 0

for i in range(n):
    num = int(input("Enter a number: "))

    if num > largest:
        largest = num

print("Largest number:", largest)

# %%
# 57. Find the smallest number among N user-entered numbers.
n = int(input("How many numbers do you want to enter? "))

smallest = int(input("Enter a number: "))

for i in range(n - 1):
    num = int(input("Enter a number: "))

    if num < smallest:
        smallest = num

print("Smallest number:", smallest)

# %%
# 58. Count positive, negative, and zero values among N inputs.
n = int(input("How many numbers do you want to enter? "))

positive = 0
negative = 0
zero = 0

for i in range(n):
    num = int(input("Enter a number: "))

    if num > 0:
        positive += 1
    elif num < 0:
        negative += 1
    else:
        zero += 1

print("Positive:", positive)
print("Negative:", negative)
print("Zero:", zero)

# %%
# 59. Find the sum of digits of each number from 1 to N.
n = int(input("Enter N: "))

for i in range(1, n + 1):
    num = i
    total = 0

    while num > 0:
        digit = num % 10
        total = total + digit
        num = num // 10

    print(i, "→", total)

# %%
# 60. Count how many numbers from 1 to N contain the digit 7.
n = int(input("Enter N: "))

count = 0

for i in range(1, n + 1):
    if '7' in str(i):
        count += 1

print("Numbers containing 7:", count)

# %%
# 61. Count the number of digits in an integer.
n = int(input("Enter a number: "))

count = 0

while n > 0:
    n = n // 10
    count += 1

print("Number of digits:", count)

# %%
# 62. Find the sum of digits of a number.
n = int(input("Enter a number: "))

total = 0

while n > 0:
    digit = n % 10
    total = total + digit
    n = n // 10

print("Sum of digits:", total)

# %%
# 63. Find the product of digits of a number.
n = int(input("Enter a number: "))

product = 1

while n > 0:
    digit = n % 10
    product = product * digit
    n = n // 10

print("Product:", product)

# %%
# 64. Reverse a number.
n = int(input("Enter a number: "))

reverse = 0

while n > 0:
    digit = n % 10
    reverse = reverse * 10 + digit
    n = n // 10

print("Reversed number:", reverse)

# %%
# 65. Check whether a number is a palindrome.
n = int(input("Enter a number; "))
original = n
reverse = 0

while n > 0:
    digit = n % 10
    reverse = reverse * 10 + digit
    n = n // 10

if original == reverse:
    print("Palindrome")
else:
    print("Not Palindrome")

# %%
# 66. Find the first digit of a number.

n = int(input("Enter a number: "))

last_digit = n % 10

print("Last digit:", last_digit)

# %%
# 68. Find the largest digit in a number.
n = int(input("Enter a number: "))

largest = 0

while n > 0:
    digit = n % 10
    if digit > largest:
        largest = digit
    n = n // 10

print("Largest digit:", largest)

# %%
# 69. Find the smallest digit in a number.
n = int(input("Enter a number: "))

smallest = 9

while n > 0:
    digit = n % 10
    if digit < smallest:
        smallest = digit
    n = n // 10

print("Smallest digit:", smallest)

# %%
# 70. Count even and odd digits.
n = int(input("Enter a number: "))

even = 0
odd = 0

while n > 0:
    digit = n % 10
    if digit % 2 == 0:
        even += 1
    else:
        odd += 1
    n = n // 10

print("Even digits:", even)
print("Odd digits:", odd)

# %%
# 71. Count the frequency of each digit 0–9.
n = int(input("Enter a number: "))

for i in range(10):
    count = 0
    num = n

    while num > 0:
        digit = num % 10

        if digit == i:
            count += 1

        num = num // 10

    print(i, "→", count)

# %%
# 72. Remove the last digit of a number repeatedly and print each intermediate value.
n = int(input("Enter a number: "))

while n > 0:
    last_digit = n % 10
    print(last_digit)
    n = n // 10

# %%
# 73. Find the number of zeros in an integer.
n = int(input("Enter a number: "))

count = 0

while n > 0:
    digit = n % 10
    if digit == 0:
        count += 1
    n = n // 10

print("Number of zeros",count)

# %%
# 74. Find the sum of first and last digits.
n = int(input("Enter a number: "))

first_digit = n % 10

last_digit = 0
while n > 0:
    last_digit = n % 10
    n = n // 1
    sum = first_digit + last_digit

print("Sum of first and last digits:", sum)

# %%
# 75. Swap the first and last digit of a number.
n = int(input("Enter a number: "))

last = n % 10

temp = n
digits = 0

while temp > 0:
    digits += 1
    temp = temp // 10

first = n // (10 ** (digits - 1))

middle = (n % (10 ** (digits - 1))) // 10

result = last * (10 ** (digits - 1)) + middle * 10 + first

print("After swapping:", result)
# Out:
# Enter a number: 45785689
# After swapping: 95785684

# %%
# 76. Check whether a number contains a particular digit.
